# %%
#สร้าง virtual environment ในครั้งแรกที่ใช้งาน

# %python -m venv venv
# Out:
# UsageError: Line magic function `%python` not found (But cell magic `%%python` exists, did you mean that instead?).

# %%
#ใช้งานเฉพาะตอนที่มีการเพิ่ม package

# %pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
#ใช้โหลด packgage ทุกอย่างที่อยู่ใน requirements.txt

# %pip install -r requirements.txt
# Out:
# ...
#
# ...
# WARNING: You are using pip version 20.2.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'c:\Witchaz\Coding\mini-project\venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
#Create dataframe
df = pd.read_csv("employee_churn_data.csv")
df
# Out:
#       department  promoted    review  projects  salary  tenure  satisfaction  \
# 0     operations         0  0.577569         3     low     5.0      0.626759
# 1     operations         0  0.751900         3  medium     6.0      0.443679
# 2        support         0  0.722548         3  medium     6.0      0.446823
# 3      logistics         0  0.675158         4    high     8.0      0.440139
# 4          sales         0  0.676203         3    high     5.0      0.577607
# ...          ...       ...       ...       ...     ...     ...           ...
# 9535  operations         0  0.610988         4  medium     8.0      0.543641
# 9536   logistics         0  0.746887         3  medium     8.0      0.549048
# 9537  operations         0  0.557980         3     low     7.0      0.705425
# 9538          IT         0  0.584446         4  medium     8.0      0.607287
# 9539     finance         0  0.626373         3     low     7.0      0.706455
#
#       bonus  avg_hrs_month left
# ...

# %%
#data cleaning
count = 0 
for i in df["department"].unique():
    df = df.replace(i,count)
    count += 1

count = 0
for i in df["salary"].unique():
    df = df.replace(i,count)
    count += 1
df
# Out:
#       department  promoted    review  projects  salary  tenure  satisfaction  \
# 0              0         0  0.577569         3       0     5.0      0.626759
# 1              0         0  0.751900         3       1     6.0      0.443679
# 2              1         0  0.722548         3       1     6.0      0.446823
# 3              2         0  0.675158         4       2     8.0      0.440139
# 4              3         0  0.676203         3       2     5.0      0.577607
# ...          ...       ...       ...       ...     ...     ...           ...
# 9535           0         0  0.610988         4       1     8.0      0.543641
# 9536           2         0  0.746887         3       1     8.0      0.549048
# 9537           0         0  0.557980         3       0     7.0      0.705425
# 9538           4         0  0.584446         4       1     8.0      0.607287
# 9539           8         0  0.626373         3       0     7.0      0.706455
#
#       bonus  avg_hrs_month left
# ...

# %%
#Create complete data 
df.to_csv("employee_churn_data_clean.csv")
